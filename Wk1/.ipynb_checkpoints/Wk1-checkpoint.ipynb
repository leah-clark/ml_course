# %% [markdown]
# # Week 1
# ## Last Time
# Last week we looked at a simple binary classification problem. We followed a process and trained a linear classifier on a simple dataset. Whilst this worked well for our toy data, when we applied it to another dataset, we found that it didn't translate too well. The reason for this is that we were trying to model a non-linear function using (essentially) the linear algeabra function that you'll have come across in high school $y=mx+c$. If you go back and try a more complicated classification method, such as [SVM](http://scikit-learn.org/stable/modules/svm.html) or [MLP](http://scikit-learn.org/stable/modules/neural_networks_supervised.html) then you'll find more success, although you will come across the bias variance tradeoff. We'll talk about this again in future weeks, but for now, let's focus on what we're doing this week.
#
# As an aside, for those of you who were wondering, the additional dataset was [the monk's problem](https://www.openml.org/d/333).
#
# For fun, we ran the data through sci-kit learn's standard implementation of a couple classifiers. We did this 5 times and the mean results are below.
#
# | Classifier | Accuracy Run 1 | Accuracy Run 2 | Accuracy Run 3 | Accuracy Run 4 | Accuracy Run 5 | Mean Accuracy |
# |:----------:|:--------------:|:--------------:|:--------------:|:--------------:|:--------------:|:-------------:|
# |     LR     |      0.643     |      0.598     |      0.643     |      0.670     |      0.643     |      0.64     |
# |     SVM$^1$    |      0.857     |      0.795     |      0.857     |      0.911     |      0.884     |     0.861     |
# |     MLP$^2$    |      0.438     |      0.455     |      0.402     |      0.554     |      0.616     |     0.493     |
#
# $^1$ By tweaking the SVM slightly, we can get it to perform with an accuracy of 0.95.
#
# $^2$ You're probably thinking this isn't too great. Neural Networks are highly parameterized and this is just an out of the box model. We could improve this greatly by changing the parameters.
#
# ## This Week
# Last week we learnt a function $f(x)=y$ that took our input features and output a discrete value $\{0,1\}$. Whilst this is OK, it clearly has its limitations, so we're going to expand on this. This week we're going to follow a similar approach and learn a function $f(x)=y$ that this time ouputs a real number rather than a discrete value. To demonstrate this we're going to try and predict house prices. We'll follow the same process as last week, but this time the dataset is more complex. Because of this there are an increased number of decisions that have to be made. We will make arbitrary decisions and highlight these. We then encourage you to take the same data and try to beat our score. The place to start will be looking at either changing the model, or going back to the arbitrary decisions that we've made and experiment with different decisions. Again, please share your results in Slack, we love to hear how you're getting on.
#
# Before we get onto this week though, let's outline a sketch of where we're going over the next couple weeks.
#
# ## Future
# The goal of these notebooks is to hopefully get you excited about ML and more importantly, to break the barrier to entry. We're not claiming that by the end of this you'll be an expert. Far from it. But we hope that you will feel confident reading other sources, building something using the tools we've introduced and are intrigued enough to find out more. With that in mind, here's where we're going.
#
# 0. Binary Classification
# 1. Regression
# 2. Multi-class Classification
# 3. Deep Learning
# 4. Clustering
# 5. Genetic Algorithms
# 6. Reinforcement Learning
#
# These are all subject to change etc, but this should give a *broad* overview of the world of machine learning. If you've got any feedback, or want to cover something different, please let us know.

# %% [markdown]
# # Predicting House Prices
#
# ## Gather the data
#
# The data is (surprisingly) in the file, 'houseprices.csv', so let's bring it in using Pandas.

# %%
import pandas as pd
train = pd.read_csv("houseprices.csv")
print(train.shape)
# Out:
# (1460, 81)

# %% [markdown]
# ## Understand the data
# The best way to get a feel for the data is to get our hands dirty. Let's take a look!
#
# We know that there are 81 rows, so printing out the rows of the dataframe will hide some of the data. Instead, let's look at one row first.

# %%
[(col, data) for col, data in zip(train.columns, train.iloc[1])]
# Out:
# [('Id', 2),
#  ('MSSubClass', 20),
#  ('MSZoning', 'RL'),
#  ('LotFrontage', 80.0),
#  ('LotArea', 9600),
#  ('Street', 'Pave'),
#  ('Alley', nan),
#  ('LotShape', 'Reg'),
#  ('LandContour', 'Lvl'),
#  ('Utilities', 'AllPub'),
#  ('LotConfig', 'FR2'),
#  ('LandSlope', 'Gtl'),
#  ('Neighborhood', 'Veenker'),
#  ('Condition1', 'Feedr'),
#  ('Condition2', 'Norm'),
#  ('BldgType', '1Fam'),
#  ('HouseStyle', '1Story'),
#  ('OverallQual', 6),
#  ('OverallCond', 8),
#  ('YearBuilt', 1976),
#  ('YearRemodAdd', 1976),
#  ('RoofStyle', 'Gable'),
#  ('RoofMatl', 'CompShg'),
#  ('Exterior1st', 'MetalSd'),
#  ('Exterior2nd', 'MetalSd'),
#  ('MasVnrType', 'None'),
#  ('MasVnrArea', 0.0),
#  ('ExterQual', 'TA'),
#  ('ExterCond', 'TA'),
#  ('Foundation', 'CBlock'),
#  ('BsmtQual', 'Gd'),
#  ('BsmtCond', 'TA'),
#  ('BsmtExposure', 'Gd'),
#  ('BsmtFinType1', 'ALQ'),
#  ('BsmtFinSF1', 978),
#  ('BsmtFinType2', 'Unf'),
#  ('BsmtFinSF2', 0),
#  ('BsmtUnfSF', 284),
#  ('TotalBsmtSF', 1262),
#  ('Heating', 'GasA'),
#  ('HeatingQC', 'Ex'),
#  ('CentralAir', 'Y'),
#  ('Electrical', 'SBrkr'),
#  ('1stFlrSF', 1262),
#  ('2ndFlrSF', 0),
#  ('LowQualFinSF', 0),
#  ('GrLivArea', 1262),
#  ('BsmtFullBath', 0),
#  ('BsmtHalfBath', 1),
#  ('FullBath', 2),
#  ('HalfBath', 0),
#  ('BedroomAbvGr', 3),
#  ('KitchenAbvGr', 1),
#  ('KitchenQual', 'TA'),
#  ('TotRmsAbvGrd', 6),
#  ('Functional', 'Typ'),
#  ('Fireplaces', 1),
#  ('FireplaceQu', 'TA'),
#  ('GarageType', 'Attchd'),
#  ('GarageYrBlt', 1976.0),
#  ('GarageFinish', 'RFn'),
#  ('GarageCars', 2),
#  ('GarageArea', 460),
#  ('GarageQual', 'TA'),
#  ('GarageCond', 'TA'),
#  ('PavedDrive', 'Y'),
#  ('WoodDeckSF', 298),
#  ('OpenPorchSF', 0),
#  ('EnclosedPorch', 0),
#  ('3SsnPorch', 0),
#  ('ScreenPorch', 0),
#  ('PoolArea', 0),
#  ('PoolQC', nan),
#  ('Fence', nan),
#  ('MiscFeature', nan),
#  ('MiscVal', 0),
#  ('MoSold', 5),
#  ('YrSold', 2007),
#  ('SaleType', 'WD'),
#  ('SaleCondition', 'Normal'),
#  ('SalePrice', 181500)]

# %% [markdown]
# First thing to notice is that there's a mix of all kinds of data, and we don't want this tutorial to take days to read through, so let's make some arbitrary decisions. These initial ones are as follows.
#
# 1. The 'Id' column can be dropped.
# 2. If a numerical column contains a NaN, the NaN is replaced with the mean of the column.
# 3. If a non-numerical column contains a NaN, the NaN is to be replaced by the string 'None'.
# 4. All text columns are to be One Hot Encoded, as we're assuming that they contain categorical data.
# 5. The column 'MSSubClass' is to be treated as containing categorical data.
#
# (Challenging some of these decisions might be a good place to look at improving the model)

# %%
import numpy as np

y = train['SalePrice'].astype(np.float64)
train = train.drop('SalePrice', axis=1)

# Rule 1
train = train.drop('Id', axis=1)

# %%
# Rules 2 & 3
for col in train.columns:
    if not train[col].dtype == object:
        mean = train[col].mean()
        train[col] = train[col].fillna(mean)
    else:
        train[col] = train[col].fillna(value="None")

# %%
# Rules 4 & 5
for col in train.columns:
    if train[col].dtype == object or col == 'MSSubClass':
        train = pd.concat([train, pd.get_dummies(train[col], prefix=col)], axis=1)
        train = train.drop(col, axis=1)

# %% [markdown]
# ## Pre-processing
# Now we've enacted those decisions, let's consider pre-processing the data. Let's arbitrarily decide to standardize all the data, including the target. Whoah whoah whoah, we're standardizing the target?! You're not crazy to think that, if you did. But ultimately, it's just a number, and as long as we're being consistent, this is a legitimate choice.

# %%
# We'll use sci-kit learn's standardizer
from sklearn.preprocessing import StandardScaler
scaler_train = StandardScaler()
scaler_test = StandardScaler()

scaler_train = scaler_train.fit(train)
scaler_test = scaler_test.fit(y.values.reshape(-1,1))

train = pd.DataFrame(scaler_train.transform(train))
y = pd.DataFrame(scaler_test.transform(y.values.reshape(-1,1)))

# %%
# Then let's split the data into training and test data
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(train, y, test_size=0.2)

# %% [markdown]
# ## Training a Model
# We're going to use an SVM as a regression model. This is again, a completely arbitrary choice. Well, kind of arbitrary, SVMs are kind of beautiful. [This](https://static1.squarespace.com/static/58851af9ebbd1a30e98fb283/t/58902fbae4fcb5398aeb7505/1485844411772/SVM+Explained.pdf) is a really nice explanation.

# %%
from sklearn import svm
model = svm.SVR(C=1e5, epsilon=1e-10, tol=1e-5)
model.fit(train_x, train_y.values.ravel())
# Out:
# SVR(C=100000.0, cache_size=200, coef0=0.0, degree=3, epsilon=1e-10,
#   gamma='auto', kernel='rbf', max_iter=-1, shrinking=True, tol=1e-05,
#   verbose=False)

# %% [markdown]
# ## Post-processing
# For post-processing, we un-standardize the output.

# %%
res = model.predict(test_x)

original_y = scaler_test.inverse_transform(test_y.values)
res_pp = scaler_test.inverse_transform(res)

# %% [markdown]
# ## Model Evaluation
#
# So how well did we do? That's a good question. There are a few different ways of measuring success when it comes to regression. Clearly if in house prices if we're a couple thousand off, that's fine. If we were trying to predict people's heights, being a couple thousand centimeteres off would be a nightmare.
#
# We're going to use [r2 score](http://scikit-learn.org/stable/modules/model_evaluation.html#r2-score-the-coefficient-of-determination) to measure success. Essentially, a score of 1.0 is the best you can get, whereas a model that makes a constant prediction whilst disrgarding the input would get an r2 score of 0.
#
# Remember, r2 score is only one method of evaluating our model. There are others and a combination of these might give a better representation of how your model is really doing. But, for now we're just going to stick with r2 score.

# %%
from sklearn.metrics import r2_score
print("r2:", r2_score(test_y.values, res))
# Out:
# r2: 0.781302236075

# %% [markdown]
# 0.78 isn't too bad. Let's look at the results and see how we did

# %%
[("target:", target, "prediction:", int(pred)) for target, pred in zip(original_y, res_pp)]
# Out:
# [('target:', array([ 119000.]), 'prediction:', 126657),
#  ('target:', array([ 125500.]), 'prediction:', 128939),
#  ('target:', array([ 122500.]), 'prediction:', 110330),
#  ('target:', array([ 146800.]), 'prediction:', 163371),
#  ('target:', array([ 144500.]), 'prediction:', 167481),
#  ('target:', array([ 155000.]), 'prediction:', 174500),
#  ('target:', array([ 164700.]), 'prediction:', 159277),
#  ('target:', array([ 150500.]), 'prediction:', 147520),
#  ('target:', array([ 205000.]), 'prediction:', 219763),
#  ('target:', array([ 105000.]), 'prediction:', 114932),
#  ('target:', array([ 214000.]), 'prediction:', 237142),
#  ('target:', array([ 124000.]), 'prediction:', 127136),
#  ('target:', array([ 148000.]), 'prediction:', 165923),
#  ('target:', array([ 130000.]), 'prediction:', 134696),
#  ('target:', array([ 118000.]), 'prediction:', 118107),
#  ('target:', array([ 194000.]), 'prediction:', 185851),
#  ('target:', array([ 107000.]), 'prediction:', 142417),
#  ('target:', array([ 79900.]), 'prediction:', 100637),
#  ('target:', array([ 205000.]), 'prediction:', 229278),
#  ('target:', array([ 192500.]), 'prediction:', 175500),
#  ('target:', array([ 118000.]), 'prediction:', 163849),
#  ('target:', array([ 164000.]), 'prediction:', 167180),
#  ('target:', array([ 154000.]), 'prediction:', 154766),
#  ('target:', array([ 385000.]), 'prediction:', 182233),
#  ('target:', array([ 299800.]), 'prediction:', 316805),
#  ('target:', array([ 60000.]), 'prediction:', 166341),
#  ('target:', array([ 139000.]), 'prediction:', 149183),
#  ('target:', array([ 230000.]), 'prediction:', 177025),
#  ('target:', array([ 80000.]), 'prediction:', 119581),
#  ('target:', array([ 110000.]), 'prediction:', 125283),
#  ('target:', array([ 220000.]), 'prediction:', 235248),
#  ('target:', array([ 127000.]), 'prediction:', 150420),
#  ('target:', array([ 185850.]), 'prediction:', 217885),
#  ('target:', array([ 113000.]), 'prediction:', 125617),
#  ('target:', array([ 96500.]), 'prediction:', 85436),
#  ('target:', array([ 107400.]), 'prediction:', 133441),
#  ('target:', array([ 242000.]), 'prediction:', 190015),
#  ('target:', array([ 126000.]), 'prediction:', 140274),
#  ('target:', array([ 176000.]), 'prediction:', 162994),
#  ('target:', array([ 200000.]), 'prediction:', 181484),
#  ('target:', array([ 120000.]), 'prediction:', 115827),
#  ('target:', array([ 106000.]), 'prediction:', 154623),
#  ('target:', array([ 137500.]), 'prediction:', 129613),
#  ('target:', array([ 611657.]), 'prediction:', 483065),
#  ('target:', array([ 87500.]), 'prediction:', 123553),
#  ('target:', array([ 145000.]), 'prediction:', 147389),
#  ('target:', array([ 215000.]), 'prediction:', 193646),
#  ('target:', array([ 755000.]), 'prediction:', 331066),
#  ('target:', array([ 120000.]), 'prediction:', 142787),
#  ('target:', array([ 219500.]), 'prediction:', 194922),
#  ('target:', array([ 132500.]), 'prediction:', 134127),
#  ('target:', array([ 226000.]), 'prediction:', 212676),
#  ('target:', array([ 85500.]), 'prediction:', 92028),
#  ('target:', array([ 275000.]), 'prediction:', 237652),
#  ('target:', array([ 582933.]), 'prediction:', 478092),
#  ('target:', array([ 90350.]), 'prediction:', 146354),
#  ('target:', array([ 230000.]), 'prediction:', 223166),
#  ('target:', array([ 134800.]), 'prediction:', 134824),
#  ('target:', array([ 82500.]), 'prediction:', 163825),
#  ('target:', array([ 126000.]), 'prediction:', 124583),
#  ('target:', array([ 266000.]), 'prediction:', 309523),
#  ('target:', array([ 159000.]), 'prediction:', 184970),
#  ('target:', array([ 144000.]), 'prediction:', 142614),
#  ('target:', array([ 137000.]), 'prediction:', 143392),
#  ('target:', array([ 178000.]), 'prediction:', 178008),
#  ('target:', array([ 163500.]), 'prediction:', 147897),
#  ('target:', array([ 160000.]), 'prediction:', 143847),
#  ('target:', array([ 134000.]), 'prediction:', 146174),
#  ('target:', array([ 86000.]), 'prediction:', 96258),
#  ('target:', array([ 147500.]), 'prediction:', 144618),
#  ('target:', array([ 260000.]), 'prediction:', 221113),
#  ('target:', array([ 136500.]), 'prediction:', 135081),
#  ('target:', array([ 138000.]), 'prediction:', 139936),
#  ('target:', array([ 266500.]), 'prediction:', 192249),
#  ('target:', array([ 136000.]), 'prediction:', 176711),
#  ('target:', array([ 227000.]), 'prediction:', 206329),
#  ('target:', array([ 115000.]), 'prediction:', 97093),
#  ('target:', array([ 197500.]), 'prediction:', 199354),
#  ('target:', array([ 325000.]), 'prediction:', 336825),
#  ('target:', array([ 121600.]), 'prediction:', 134456),
#  ('target:', array([ 137500.]), 'prediction:', 116100),
#  ('target:', array([ 169500.]), 'prediction:', 157279),
#  ('target:', array([ 134900.]), 'prediction:', 143920),
#  ('target:', array([ 228500.]), 'prediction:', 229214),
#  ('target:', array([ 135000.]), 'prediction:', 144399),
#  ('target:', array([ 143000.]), 'prediction:', 182267),
#  ('target:', array([ 255900.]), 'prediction:', 258995),
#  ('target:', array([ 202500.]), 'prediction:', 205056),
#  ('target:', array([ 129000.]), 'prediction:', 150327),
#  ('target:', array([ 187000.]), 'prediction:', 186355),
#  ('target:', array([ 140000.]), 'prediction:', 137360),
#  ('target:', array([ 135000.]), 'prediction:', 143160),
#  ('target:', array([ 174000.]), 'prediction:', 171938),
#  ('target:', array([ 192000.]), 'prediction:', 193591),
#  ('target:', array([ 173000.]), 'prediction:', 166199),
#  ('target:', array([ 104900.]), 'prediction:', 125521),
#  ('target:', array([ 151000.]), 'prediction:', 162706),
#  ('target:', array([ 244400.]), 'prediction:', 208603),
#  ('target:', array([ 67000.]), 'prediction:', 81965),
#  ('target:', array([ 118000.]), 'prediction:', 108756),
#  ('target:', array([ 188700.]), 'prediction:', 210795),
#  ('target:', array([ 173900.]), 'prediction:', 170096),
#  ('target:', array([ 180500.]), 'prediction:', 167000),
#  ('target:', array([ 125000.]), 'prediction:', 143031),
#  ('target:', array([ 249700.]), 'prediction:', 257708),
#  ('target:', array([ 150900.]), 'prediction:', 161871),
#  ('target:', array([ 279500.]), 'prediction:', 216268),
#  ('target:', array([ 278000.]), 'prediction:', 267771),
#  ('target:', array([ 176432.]), 'prediction:', 161985),
#  ('target:', array([ 155000.]), 'prediction:', 164215),
#  ('target:', array([ 202500.]), 'prediction:', 203865),
#  ('target:', array([ 275000.]), 'prediction:', 215727),
#  ('target:', array([ 88000.]), 'prediction:', 88382),
#  ('target:', array([ 192000.]), 'prediction:', 163983),
#  ('target:', array([ 315750.]), 'prediction:', 331461),
#  ('target:', array([ 230000.]), 'prediction:', 217892),
#  ('target:', array([ 129000.]), 'prediction:', 128306),
#  ('target:', array([ 144000.]), 'prediction:', 162520),
#  ('target:', array([ 131500.]), 'prediction:', 150391),
#  ('target:', array([ 185000.]), 'prediction:', 184396),
#  ('target:', array([ 333168.]), 'prediction:', 296939),
#  ('target:', array([ 264561.]), 'prediction:', 269202),
#  ('target:', array([ 361919.]), 'prediction:', 417226),
#  ('target:', array([ 178000.]), 'prediction:', 181870),
#  ('target:', array([ 215000.]), 'prediction:', 229082),
#  ('target:', array([ 172000.]), 'prediction:', 179597),
#  ('target:', array([ 152000.]), 'prediction:', 122412),
#  ('target:', array([ 164500.]), 'prediction:', 180911),
#  ('target:', array([ 313000.]), 'prediction:', 295309),
#  ('target:', array([ 424870.]), 'prediction:', 414662),
#  ('target:', array([ 82500.]), 'prediction:', 108058),
#  ('target:', array([ 81000.]), 'prediction:', 89930),
#  ('target:', array([ 86000.]), 'prediction:', 99244),
#  ('target:', array([ 178000.]), 'prediction:', 195590),
#  ('target:', array([ 109000.]), 'prediction:', 141300),
#  ('target:', array([ 153337.]), 'prediction:', 168523),
#  ('target:', array([ 144000.]), 'prediction:', 142442),
#  ('target:', array([ 244000.]), 'prediction:', 228772),
#  ('target:', array([ 225000.]), 'prediction:', 238963),
#  ('target:', array([ 224900.]), 'prediction:', 210203),
#  ('target:', array([ 155000.]), 'prediction:', 150366),
#  ('target:', array([ 127000.]), 'prediction:', 153433),
#  ('target:', array([ 138000.]), 'prediction:', 142237),
#  ('target:', array([ 262500.]), 'prediction:', 284670),
#  ('target:', array([ 93000.]), 'prediction:', 104930),
#  ('target:', array([ 160000.]), 'prediction:', 170980),
#  ('target:', array([ 171750.]), 'prediction:', 201661),
#  ('target:', array([ 465000.]), 'prediction:', 404238),
#  ('target:', array([ 90000.]), 'prediction:', 124790),
#  ('target:', array([ 109500.]), 'prediction:', 96312),
#  ('target:', array([ 220000.]), 'prediction:', 204347),
#  ('target:', array([ 129000.]), 'prediction:', 140061),
#  ('target:', array([ 109000.]), 'prediction:', 109491),
#  ('target:', array([ 335000.]), 'prediction:', 302136),
#  ('target:', array([ 118500.]), 'prediction:', 153991),
#  ('target:', array([ 181000.]), 'prediction:', 184864),
#  ('target:', array([ 107900.]), 'prediction:', 99015),
#  ('target:', array([ 130000.]), 'prediction:', 135543),
#  ('target:', array([ 143000.]), 'prediction:', 158480),
#  ('target:', array([ 285000.]), 'prediction:', 263660),
#  ('target:', array([ 214500.]), 'prediction:', 160853),
#  ('target:', array([ 153000.]), 'prediction:', 153816),
#  ('target:', array([ 165500.]), 'prediction:', 160685),
#  ('target:', array([ 228950.]), 'prediction:', 178314),
#  ('target:', array([ 114500.]), 'prediction:', 112405),
#  ('target:', array([ 225000.]), 'prediction:', 201170),
#  ('target:', array([ 133000.]), 'prediction:', 135387),
#  ('target:', array([ 156000.]), 'prediction:', 166615),
#  ('target:', array([ 132500.]), 'prediction:', 137484),
#  ('target:', array([ 144000.]), 'prediction:', 127021),
#  ('target:', array([ 82000.]), 'prediction:', 164085),
#  ('target:', array([ 239900.]), 'prediction:', 221782),
#  ('target:', array([ 91000.]), 'prediction:', 107517),
#  ('target:', array([ 195000.]), 'prediction:', 183999),
#  ('target:', array([ 119500.]), 'prediction:', 121022),
#  ('target:', array([ 230000.]), 'prediction:', 219871),
#  ('target:', array([ 171900.]), 'prediction:', 146546),
#  ('target:', array([ 227875.]), 'prediction:', 261049),
#  ('target:', array([ 277000.]), 'prediction:', 231753),
#  ('target:', array([ 98000.]), 'prediction:', 111784),
#  ('target:', array([ 157900.]), 'prediction:', 142809),
#  ('target:', array([ 115000.]), 'prediction:', 104479),
#  ('target:', array([ 240000.]), 'prediction:', 224773),
#  ('target:', array([ 108959.]), 'prediction:', 157881),
#  ('target:', array([ 280000.]), 'prediction:', 235759),
#  ('target:', array([ 127000.]), 'prediction:', 116008),
#  ('target:', array([ 144000.]), 'prediction:', 132992),
#  ('target:', array([ 430000.]), 'prediction:', 337309),
#  ('target:', array([ 135000.]), 'prediction:', 138449),
#  ('target:', array([ 172500.]), 'prediction:', 177121),
#  ('target:', array([ 185750.]), 'prediction:', 186311),
#  ('target:', array([ 169500.]), 'prediction:', 157195),
#  ('target:', array([ 254900.]), 'prediction:', 248582),
#  ('target:', array([ 163000.]), 'prediction:', 157351),
#  ('target:', array([ 164000.]), 'prediction:', 154375),
#  ('target:', array([ 80000.]), 'prediction:', 98206),
#  ('target:', array([ 129900.]), 'prediction:', 121347),
#  ('target:', array([ 139400.]), 'prediction:', 132308),
#  ('target:', array([ 179540.]), 'prediction:', 181518),
#  ('target:', array([ 147000.]), 'prediction:', 164954),
#  ('target:', array([ 172785.]), 'prediction:', 169989),
#  ('target:', array([ 191000.]), 'prediction:', 181774),
#  ('target:', array([ 241500.]), 'prediction:', 171392),
#  ('target:', array([ 117000.]), 'prediction:', 140874),
#  ('target:', array([ 139500.]), 'prediction:', 135321),
#  ('target:', array([ 185000.]), 'prediction:', 185170),
#  ('target:', array([ 105000.]), 'prediction:', 106582),
#  ('target:', array([ 207500.]), 'prediction:', 213618),
#  ('target:', array([ 231500.]), 'prediction:', 206637),
#  ('target:', array([ 213500.]), 'prediction:', 188792),
#  ('target:', array([ 143500.]), 'prediction:', 162092),
#  ('target:', array([ 135000.]), 'prediction:', 128863),
#  ('target:', array([ 147000.]), 'prediction:', 151041),
#  ('target:', array([ 147000.]), 'prediction:', 173798),
#  ('target:', array([ 95000.]), 'prediction:', 143020),
#  ('target:', array([ 145000.]), 'prediction:', 148776),
#  ('target:', array([ 211000.]), 'prediction:', 214592),
#  ('target:', array([ 181500.]), 'prediction:', 189508),
#  ('target:', array([ 80000.]), 'prediction:', 70409),
#  ('target:', array([ 283463.]), 'prediction:', 278922),
#  ('target:', array([ 110000.]), 'prediction:', 131644),
#  ('target:', array([ 89500.]), 'prediction:', 84366),
#  ('target:', array([ 286000.]), 'prediction:', 276898),
#  ('target:', array([ 132000.]), 'prediction:', 135768),
#  ('target:', array([ 120000.]), 'prediction:', 123164),
#  ('target:', array([ 125000.]), 'prediction:', 111882),
#  ('target:', array([ 160000.]), 'prediction:', 161561),
#  ('target:', array([ 154000.]), 'prediction:', 153784),
#  ('target:', array([ 345000.]), 'prediction:', 366835),
#  ('target:', array([ 185900.]), 'prediction:', 198702),
#  ('target:', array([ 115000.]), 'prediction:', 117036),
#  ('target:', array([ 172500.]), 'prediction:', 163565),
#  ('target:', array([ 224000.]), 'prediction:', 240237),
#  ('target:', array([ 178000.]), 'prediction:', 171883),
#  ('target:', array([ 139000.]), 'prediction:', 121767),
#  ('target:', array([ 188000.]), 'prediction:', 148284),
#  ('target:', array([ 170000.]), 'prediction:', 166722),
#  ('target:', array([ 140000.]), 'prediction:', 163180),
#  ('target:', array([ 145000.]), 'prediction:', 141157),
#  ('target:', array([ 97500.]), 'prediction:', 119123),
#  ('target:', array([ 136500.]), 'prediction:', 125222),
#  ('target:', array([ 167900.]), 'prediction:', 165947),
#  ('target:', array([ 119000.]), 'prediction:', 126274),
#  ('target:', array([ 275500.]), 'prediction:', 246145),
#  ('target:', array([ 237000.]), 'prediction:', 254591),
#  ('target:', array([ 159000.]), 'prediction:', 176899),
#  ('target:', array([ 114500.]), 'prediction:', 130638),
#  ('target:', array([ 251000.]), 'prediction:', 276193),
#  ('target:', array([ 102000.]), 'prediction:', 108424),
#  ('target:', array([ 142500.]), 'prediction:', 126055),
#  ('target:', array([ 145500.]), 'prediction:', 132430),
#  ('target:', array([ 177000.]), 'prediction:', 168501),
#  ('target:', array([ 395000.]), 'prediction:', 289110),
#  ('target:', array([ 90000.]), 'prediction:', 139073),
#  ('target:', array([ 135000.]), 'prediction:', 131482),
#  ('target:', array([ 200500.]), 'prediction:', 209189),
#  ('target:', array([ 250000.]), 'prediction:', 202956),
#  ('target:', array([ 184000.]), 'prediction:', 173676),
#  ('target:', array([ 177000.]), 'prediction:', 191711),
#  ('target:', array([ 183200.]), 'prediction:', 182265),
#  ('target:', array([ 127000.]), 'prediction:', 135675),
#  ('target:', array([ 91500.]), 'prediction:', 93004),
#  ('target:', array([ 287000.]), 'prediction:', 229698),
#  ('target:', array([ 118400.]), 'prediction:', 120930),
#  ('target:', array([ 152000.]), 'prediction:', 153586),
#  ('target:', array([ 112000.]), 'prediction:', 96078),
#  ('target:', array([ 149350.]), 'prediction:', 141706),
#  ('target:', array([ 154300.]), 'prediction:', 160241),
#  ('target:', array([ 134432.]), 'prediction:', 132272),
#  ('target:', array([ 117000.]), 'prediction:', 123765),
#  ('target:', array([ 315000.]), 'prediction:', 210344),
#  ('target:', array([ 130500.]), 'prediction:', 166275),
#  ('target:', array([ 394432.]), 'prediction:', 411134),
#  ('target:', array([ 186500.]), 'prediction:', 199225),
#  ('target:', array([ 115000.]), 'prediction:', 152230),
#  ('target:', array([ 125000.]), 'prediction:', 123844),
#  ('target:', array([ 191000.]), 'prediction:', 191416),
#  ('target:', array([ 173500.]), 'prediction:', 170319),
#  ('target:', array([ 260000.]), 'prediction:', 266777),
#  ('target:', array([ 255000.]), 'prediction:', 266955),
#  ('target:', array([ 200000.]), 'prediction:', 165074),
#  ('target:', array([ 171000.]), 'prediction:', 160198),
#  ('target:', array([ 149500.]), 'prediction:', 160129),
#  ('target:', array([ 324000.]), 'prediction:', 188600),
#  ('target:', array([ 99900.]), 'prediction:', 96403),
#  ('target:', array([ 112000.]), 'prediction:', 122721),
#  ('target:', array([ 129000.]), 'prediction:', 128903),
#  ('target:', array([ 181000.]), 'prediction:', 163989),
#  ('target:', array([ 113000.]), 'prediction:', 115983),
#  ('target:', array([ 168000.]), 'prediction:', 169547),
#  ('target:', array([ 248900.]), 'prediction:', 233189),
#  ('target:', array([ 190000.]), 'prediction:', 179972)]

# %% [markdown]
# You can see, some of these have turned out well...... others, not so much. But an r2 score of 0.78 feels like a good challenge to try and beat. Particularly given the number of arbitrary decisions in pre-processing. Let us know how you get on :)
